# %%
# Case Study
# predicting hossing prices 
# Senario : A real Esate acengcy wants to predict hosuing prices based on different property features such as square foot age, no fo bed rooms and location.
# Accurate price predictions can help agents set fair property values and assit buyers in making informed decisions.

# Objective: Develop a Regression model to predict the price of a house using key property features.
# Task: 
# 1) Collect and Preprocess the housing data
# 2) train a Linear regression model using Sklearn
# 3) Evaluate the model's performance and interpert the coefficients

# Concepts: This problem uses supervised learning (regression) - where the model learns from labeled data (features + target price) and predicts continious values such as house prices.

# Steps: 
# 1) Importing the packages or required libs
# 2) Create or load a small dataset
# 3) Split the data into training and testing
# 4) Train a Linear regression model
# 5) Evaluate model performance using metrics like R^2_score
